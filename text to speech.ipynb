# %%
pip install pyttsx3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyttsx3

# %%
speaker = pyttsx3.init()
speaker.say("welcome honey paaji")
speaker.runAndWait()
