# %%
pip install twilio
# Out:
# Requirement already satisfied: twilio in c:\users\dell\anaconda3\lib\site-packages (9.8.7)
# Requirement already satisfied: requests>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from twilio) (2.32.3)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from twilio) (2.10.1)
# Requirement already satisfied: aiohttp>=3.8.4 in c:\users\dell\anaconda3\lib\site-packages (from twilio) (3.11.10)
# Requirement already satisfied: aiohttp-retry>=2.8.3 in c:\users\dell\anaconda3\lib\site-packages (from twilio) (2.9.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (1.18.0)
# Requirement already satisfied: idna>=2.0 in c:\users\dell\anaconda3\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.8.4->twilio) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %%
from twilio.rest import Client

ACCOUNT_SID="TWILIO_ACCOUNT_SID"
AUTH_TOKEN="TWILIO_AUTH_TOKEN"

TWILIO_NUMBER= "+1234567890"
RECEIVER_NUMBER= "+919XXXXXXXXX"

client = Client(ACCOUNT_SID,AUTH_TOKEN)

message = client.messages.create(
    body="Hello, Nakul This Side",
    from_=TWILIO_NUMBER,
    to=RECEIVER_NUMBER
)
