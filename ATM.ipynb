# %%
while True:
 balance = 5000
 pin = 1234

 user_pin = int (input("Enter your Pin:"))

 if user_pin == pin :
    print("Your balance is : " , balance)
    amount = int (input ("Enter amount to withdrawl : "))
    balance -= amount # balance = balance - amount
    print (" congrates Amount recived " , "New balance is " , balance)
 else:
    break
